# %%
import pandas as pd

# %%
# The path to our CSV file
gunviolence_file = "datasets/gun_violence_data.csv"

# Read our Kickstarter data into pandas
df = pd.read_csv(gunviolence_file)
df.head()
# Out:
#      date           state city_or_county  n_killed  n_injured  \
# 0  1/1/13    Pennsylvania     Mckeesport         0          4
# 1  1/1/13      California      Hawthorne         1          3
# 2  1/1/13            Ohio         Lorain         1          3
# 3  1/5/13        Colorado         Aurora         4          0
# 4  1/7/13  North Carolina     Greensboro         2          2
#
#    congressional_district              gun_stolen                gun_type  \
# 0                    14.0                     NaN                     NaN
# 1                    43.0                     NaN                     NaN
# 2                     9.0  0::Unknown||1::Unknown  0::Unknown||1::Unknown
# 3                     6.0                     NaN                     NaN
# 4                     6.0  0::Unknown||1::Unknown  0::Handgun||1::Handgun
#
#                             incident_characteristics  latitude  longitude
# 0  Shot - Wounded/Injured||Mass Shooting (4+ vict...   40.3467   -79.8559
# 1  Shot - Wounded/Injured||Shot - Dead (murder, a...   33.9090  -118.3330
# 2  Shot - Wounded/Injured||Shot - Dead (murder, a...   41.4455   -82.1377
# 3  Shot - Dead (murder, accidental, suicide)||Off...   39.6518  -104.8020
# 4  Shot - Wounded/Injured||Shot - Dead (murder, a...   36.1140   -79.9569

# %%
df.columns
# Out:
# Index(['date', 'state', 'city_or_county', 'n_killed', 'n_injured',
#        'congressional_district', 'gun_stolen', 'gun_type',
#        'incident_characteristics', 'latitude', 'longitude'],
#       dtype='object')

# %%
reduced_gunviolence_df = df.loc[:, ['date', 'state', 'city_or_county', 'n_killed', 'n_injured', 
                                    'gun_stolen', 'gun_type',
       'incident_characteristics', 'latitude', 'longitude']]
reduced_gunviolence_df
# Out:
#            date           state city_or_county  n_killed  n_injured  \
# 0        1/1/13    Pennsylvania     Mckeesport         0          4
# 1        1/1/13      California      Hawthorne         1          3
# 2        1/1/13            Ohio         Lorain         1          3
# 3        1/5/13        Colorado         Aurora         4          0
# 4        1/7/13  North Carolina     Greensboro         2          2
# ...         ...             ...            ...       ...        ...
# 239672  3/31/18       Louisiana          Rayne         0          0
# 239673  3/31/18       Louisiana   Natchitoches         1          0
# 239674  3/31/18       Louisiana         Gretna         0          1
# 239675  3/31/18           Texas        Houston         1          0
# 239676  3/31/18           Maine   Norridgewock         2          0
#
#                     gun_stolen                gun_type  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2       0::Unknown||1::Unknown  0::Unknown||1::Unknown
# 3                          NaN                     NaN
# 4       0::Unknown||1::Unknown  0::Handgun||1::Handgun
# ...                        ...                     ...
# 239672              0::Unknown              0::Unknown
# 239673              0::Unknown              0::Unknown
# 239674              0::Unknown              0::Unknown
# 239675              0::Unknown              0::Unknown
# 239676  0::Unknown||1::Unknown  0::Handgun||1::Shotgun
#
#                                  incident_characteristics  latitude  longitude
# 0       Shot - Wounded/Injured||Mass Shooting (4+ vict...   40.3467   -79.8559
# 1       Shot - Wounded/Injured||Shot - Dead (murder, a...   33.9090  -118.3330
# 2       Shot - Wounded/Injured||Shot - Dead (murder, a...   41.4455   -82.1377
# 3       Shot - Dead (murder, accidental, suicide)||Off...   39.6518  -104.8020
# 4       Shot - Wounded/Injured||Shot - Dead (murder, a...   36.1140   -79.9569
# ...                                                   ...       ...        ...
# 239672                          Shots Fired - No Injuries       NaN        NaN
# 239673  Shot - Dead (murder, accidental, suicide)||Ins...   31.7537   -93.0836
# 239674                             Shot - Wounded/Injured   29.9239   -90.0442
# 239675          Shot - Dead (murder, accidental, suicide)   29.7201   -95.6110
# 239676  Shot - Dead (murder, accidental, suicide)||Sui...   44.7293   -69.7691
#
# [239677 rows x 10 columns]

# %%
# Rename columns
reduced_gunviolence_df.columns = [
    'date', 'state', 'city_or_county', 'n_killed', 'n_inj', 
    'gun_stolen', 'gun_type','characteristics', 'lat', 'long']

# %%
reduced_gunviolence_df.columns
# Out:
# Index(['date', 'state', 'city_or_county', 'n_killed', 'n_inj', 'gun_stolen',
#        'gun_type', 'characteristics', 'lat', 'long'],
#       dtype='object')

# %%
reduced_gunviolence_df
# Out:
#            date           state city_or_county  n_killed  n_inj  \
# 0        1/1/13    Pennsylvania     Mckeesport         0      4
# 1        1/1/13      California      Hawthorne         1      3
# 2        1/1/13            Ohio         Lorain         1      3
# 3        1/5/13        Colorado         Aurora         4      0
# 4        1/7/13  North Carolina     Greensboro         2      2
# ...         ...             ...            ...       ...    ...
# 239672  3/31/18       Louisiana          Rayne         0      0
# 239673  3/31/18       Louisiana   Natchitoches         1      0
# 239674  3/31/18       Louisiana         Gretna         0      1
# 239675  3/31/18           Texas        Houston         1      0
# 239676  3/31/18           Maine   Norridgewock         2      0
#
#                     gun_stolen                gun_type  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2       0::Unknown||1::Unknown  0::Unknown||1::Unknown
# 3                          NaN                     NaN
# 4       0::Unknown||1::Unknown  0::Handgun||1::Handgun
# ...                        ...                     ...
# 239672              0::Unknown              0::Unknown
# 239673              0::Unknown              0::Unknown
# 239674              0::Unknown              0::Unknown
# 239675              0::Unknown              0::Unknown
# 239676  0::Unknown||1::Unknown  0::Handgun||1::Shotgun
#
#                                           characteristics      lat      long
# 0       Shot - Wounded/Injured||Mass Shooting (4+ vict...  40.3467  -79.8559
# 1       Shot - Wounded/Injured||Shot - Dead (murder, a...  33.9090 -118.3330
# 2       Shot - Wounded/Injured||Shot - Dead (murder, a...  41.4455  -82.1377
# 3       Shot - Dead (murder, accidental, suicide)||Off...  39.6518 -104.8020
# 4       Shot - Wounded/Injured||Shot - Dead (murder, a...  36.1140  -79.9569
# ...                                                   ...      ...       ...
# 239672                          Shots Fired - No Injuries      NaN       NaN
# 239673  Shot - Dead (murder, accidental, suicide)||Ins...  31.7537  -93.0836
# 239674                             Shot - Wounded/Injured  29.9239  -90.0442
# 239675          Shot - Dead (murder, accidental, suicide)  29.7201  -95.6110
# 239676  Shot - Dead (murder, accidental, suicide)||Sui...  44.7293  -69.7691
#
# [239677 rows x 10 columns]
